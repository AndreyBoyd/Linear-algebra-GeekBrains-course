# %% [markdown]
# ### Урок 6
#
# ##### 1. Решить систему уравнений методом Гаусса:
#
# $$\begin{cases}
# x_{1}+x_{2}-x_{3}-2x_{4}=0, \\
# 2x_{1}+x_{2}-x_{3}+x_{4}=-2, \\
# x_{1}+x_{2}-3x_{3}+x_{4}=4.
# \end{cases}$$
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2 \\
# 2 & 1 & -1 & 1 \\
# 1 & 1 & -3 & 1
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -2\\
# 4
# \end{matrix}
# \end{pmatrix}$$
#
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2\\
# 0 & -1 & 1 & 5\\
# 1 & 1 & -3 & 1
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -2\\
# 4
# \end{matrix}
# \end{pmatrix}$$
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2\\
# 0 & -1 & 1 & 5\\
# 0 & 0 & -2 & 3
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -2\\
# 4
# \end{matrix}
# \end{pmatrix}$$
# Система имеет бесконечное кол-во решений.
#
# Делим третью строку на 3:
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2\\
# 0 & -1 & 1 & 5\\
# 0 & 0 & -\frac{2}{3} & 1
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -2\\
# \frac{4}{3}
# \end{matrix}
# \end{pmatrix}$$
#
# Получаем систему уравнений:
#
# $$\begin{cases}
# x_{1} + x_{2} - x_{3} -2 \cdot x_{4} = 0, \\
# -x_{2} + x_{3} + 5 \cdot x_{4} = -2, \\
# -\frac{2}{3} \cdot x_{3} + x_{4} = \frac{4}{3}
# \end{cases}$$
#
# Система имеет бесконечное множество решений и в общем виде может быть записана как:
#
# $x_{4}=c,$
#
# $x_{3}=\frac{4-3c}{-2} \;$
#
# $x_{2}=2 + 5 \cdot c + \frac{4-3c}{-2},$
#
# $x_{1}=-2 -3 \cdot c.$

# %% [markdown]
# ##### 2. Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений:
#
# ##### а) $\begin{cases}
# 3x_{1}-x_{2}+x_{3}=4, \\
# 2x_{1}-5x_{2}-3x_{3}=-17, \\
# x_{1}+x_{2}-x_{3}=0;
# \end{cases}$
#
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 3 & -1 & 1 \\
# 2 & -5 & -3 \\
# 1 & 1 & -1
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# -17\\
# 0
# \end{matrix}
# \end{pmatrix}$$
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & -\frac{1}{3} & \frac{1}{3} \\
# 2 & -5 & -3 \\
# 1 & 1 & -1
# \end{matrix}\right|
# \begin{matrix}
# \frac{4}{3}\\
# -17\\
# 0
# \end{matrix}
# \end{pmatrix}$$
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & -\frac{1}{3} & \frac{1}{3} \\
# 0 & -\frac{13}{3} & -\frac{11}{3} \\
# 1 & 1 & -1
# \end{matrix}\right|
# \begin{matrix}
# \frac{4}{3}\\
# -\frac{59}{3}\\
# 0
# \end{matrix}
# \end{pmatrix}$$
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & -\frac{1}{3} & \frac{1}{3} \\
# 0 & -\frac{13}{3} & -\frac{11}{3} \\
# 0 & \frac{4}{3} & -\frac{4}{3}
# \end{matrix}\right|
# \begin{matrix}
# \frac{4}{3}\\
# -\frac{59}{3}\\
# -\frac{4}{3}
# \end{matrix}
# \end{pmatrix}$$
#
# Умножаем вторую строку на $-\frac{3}{13}$, и отнимем вторую строку из третьей:
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & -\frac{1}{3} & \frac{1}{3} \\
# 0 & 1 & \frac{11}{13} \\
# 0 & 0 & \frac{24}{13}
# \end{matrix}\right|
# \begin{matrix}
# \frac{4}{3}\\
# \frac{59}{13}\\
# \frac{72}{13}
# \end{matrix}
# \end{pmatrix}$$
#
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & -\frac{1}{3} & \frac{1}{3} \\
# 0 & 1 & \frac{11}{13} \\
# 0 & 0 & 1
# \end{matrix}\right|
# \begin{matrix}
# \frac{4}{3}\\
# \frac{59}{13}\\
# 3
# \end{matrix}
# \end{pmatrix}$$
# $rangA=rang(A|B)=n$,
# ##### Ответ: система совместная и определенная т.е. имеет 1 решение.

# %% [markdown]
# ##### б) $\begin{cases}
# 2x_{1}-4x_{2}+6x_{3}=1, \\
# x_{1}-2x_{2}+3x_{3}=-2, \\
# 3x_{1}-6x_{2}+9x_{3}=5;
# \end{cases}$
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 2 & -4 & 6 \\
# 1 & -2 & 3 \\
# 3 & 6 & -9
# \end{matrix}\right|
# \begin{matrix}
# 1\\
# -2\\
# 5
# \end{matrix}
# \end{pmatrix}$$
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & -2 & 3 \\
# 1 & -2 & 3 \\
# 3 & 6 & -9
# \end{matrix}\right|
# \begin{matrix}
# 0.5\\
# -2\\
# 5
# \end{matrix}
# \end{pmatrix}$$
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & -2 & 3 \\
# 0 & 0 & 0 \\
# 3 & 6 & -9
# \end{matrix}\right|
# \begin{matrix}
# 0.5\\
# -2.5\\
# 5
# \end{matrix}
# \end{pmatrix}$$
#
# Отнимаем из третьей строки первую, умноженную на 3:
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & -2 & 3 \\
# 0 & 0 & 0 \\
# 0 & 0 & 0
# \end{matrix}\right|
# \begin{matrix}
# 0.5\\
# -2.5\\
# 3.5
# \end{matrix}
# \end{pmatrix}$$
#
# Делим вторую строку на -2.5:
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & -2 & 3 \\
# 0 & 0 & 0 \\
# 0 & 0 & 0
# \end{matrix}\right|
# \begin{matrix}
# 0.5\\
# 1\\
# 3.5
# \end{matrix}
# \end{pmatrix}$$
#
# Отнимаем из третьей строки вторую, умноженную на 3.5:
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & -2 & 3 \\
# 0 & 0 & 0 \\
# 0 & 0 & 0
# \end{matrix}\right|
# \begin{matrix}
# 0.5\\
# 1\\
# 0
# \end{matrix}
# \end{pmatrix}$$
# $rangA$ не равен $rang(A|B)$,
#
# ##### Ответ: Система несовместная, т.е. не имеет решений.

# %% [markdown]
# ##### в) $\begin{cases}
# x_{1}+2x_{2}+5x_{3}=4, \\
# 3x_{1}+x_{2}-8x_{3}=-2.
# \end{cases}$
#
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 5 \\
# 3 & 1 & -8
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# -2
# \end{matrix}
# \end{pmatrix}$$
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 5 \\
# 0 & -5 & -23
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# -14
# \end{matrix}
# \end{pmatrix}$$
#
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 5 \\
# 0 & 1 & \frac{23}{5}
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# \frac{14}{5}
# \end{matrix}
# \end{pmatrix}$$
# $rangA=rang(A|B)<n$,
#
# ##### Ответ: Система совместная и определенная, т.е. имеет как минимум 2 решения.

# %% [markdown]
# ##### 3. Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений, заданная расширенной матрицей
#
# $$\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 3 & -2 & 4\\
# 0 & 5 & 0 & 1\\
# 0 & 0 & 3 & 0\\
# 0 & 0 & 0 & 2
# \end{matrix}\right|
# \begin{matrix}
# 3\\
# 2\\
# 4\\
# 1
# \end{matrix}
# \end{pmatrix}.$$
# $rang(A)=rang(A|B)=n$,
#
# ##### Ответ: Система совместная и определенная, т.е. имеет 1 решение.

# %% [markdown]
# ##### 4. Дана система линейных уравнений, заданная расширенной матрицей
#
# $$\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b\\
# c
# \end{matrix}
# \end{pmatrix}.$$
# ##### Найти соотношение между параметрами $a$, $b$ и $c$, при которых система является несовместной.
#
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 0 & -3 & -6\\
# 7 & 8 & 9
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b-4 \cdot a\\
# c
# \end{matrix}
# \end{pmatrix}$$
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 0 & -3 & -6\\
# 0 & -6 & -12
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b-4 \cdot a\\
# c-7 \cdot a
# \end{matrix}
# \end{pmatrix}$$
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 0 & -3 & -6\\
# 0 & 0 & 0
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b-4 \cdot a\\
# c-7 \cdot a + 2\cdot b -8\cdot a
# \end{matrix}
# \end{pmatrix}$$
#
# ##### Ответ: При $(-15 \cdot a + 2\cdot b + c)\neq0$ система является несовместной.

# %% [markdown]
# ### Урок 7

# %% [markdown]
# ##### 5. Решить систему уравнений методом Крамера:
#
# ##### а) $\begin{cases}
# x_{1}-2x_{2}=1 \\
# 3x_{1}-4x_{2}=7
# \end{cases}$
#
# $detA=\begin{vmatrix}
# 1 & -2\\
# 3 & -4\\
# \end{vmatrix}=(1 \cdot -4) - (-2 \cdot 3) = 2$
#
#
# $detA_{1}=\begin{vmatrix}
# 1 & -2\\
# 7 & -4\\
# \end{vmatrix}=(1 \cdot -4) - (-2 \cdot 7) = 10$
#
#
# $detA_{2}=\begin{vmatrix}
# 1 & 1\\
# 3 & 1\\
# \end{vmatrix}=(1 \cdot 7) - (1 \cdot 3) = 4$
#
# $x_{1}=10/2=5$
#
# $x_{2}=4/2=2$
#
#
# $\begin{cases}
# 5-4=1 \\
# 15-8=7
# \end{cases}$
#
#
#
#
# #### б) $\begin{cases}
# 2x_{1}-x_{2}+5x_{3}=10 \\
# x_{1}+x_{2}-3x_{3}=-2 \\
# 2x_{1}+4x_{2}+x_{3}=1
# \end{cases}$
#
#
# $detA=\begin{vmatrix}
# 2 & -1 & 5\\
# 1 & -1 & -3\\
# 2 & 4 & 1
# \end{vmatrix}=(2 \cdot 1 \cdot 1) + (-1 \cdot -3 \cdot 2) + (5 \cdot 1 \cdot 4) - (5 \cdot 1 \cdot 2) - (2 \cdot -3 \cdot 4) - (-1 \cdot 1 \cdot 1) = 43$
#
# $detA_{1}=\begin{vmatrix}
# 10 & -1 & 5\\
# -2 & -1 & -3\\
# 1 & 4 & 1
# \end{vmatrix}=(10 \cdot 1 \cdot 1) + (-1 \cdot -3 \cdot 1) + (5 \cdot -2 \cdot 4) - (5 \cdot 1 \cdot 1) - (10 \cdot -3 \cdot 4) - (-1 \cdot -2 \cdot 1) = 86$
#
# Найдем определитель $detA_{2}$:
#
# $detA_{2}=\begin{vmatrix}
# 2 & 10 & 5\\
# 1 & -2 & -3\\
# 2 & 1 & 1
# \end{vmatrix}=(2 \cdot -2 \cdot 1) + (10 \cdot -3 \cdot 2) + (5 \cdot 1 \cdot 1) - (5 \cdot -2 \cdot 2) - (2 \cdot -3 \cdot 1) - (10 \cdot 1 \cdot 1) = -43$
#
# Найдем определитель $detA_{3}$:
#
# $detA_{3}=\begin{vmatrix}
# 2 & -1 & 10\\
# 1 & -1 & -2\\
# 2 & 4 & 1
# \end{vmatrix}=(2 \cdot 1 \cdot 1) + (-1 \cdot -2 \cdot 2) + (10 \cdot 1 \cdot 4) - (10 \cdot 1 \cdot 2) - (2 \cdot -2 \cdot 4) - (-1 \cdot 1 \cdot 1) = 43$
#
# Найдем значения $x_{1}, x_{2}, x_{3}$:
#
# $x_{1}=86/43=2$
#
# $x_{2}=-43/43=-1$
#
# $x_{3}=43/43=1$
#
# $\begin{cases}
# 4+1+5=10 \\
# 2-1-3=-2 \\
# 4-4+1=1
# \end{cases}$

# %% [markdown]
# #### Задания со звездочкой решил не делать так как требуют много времени для выполнения.
